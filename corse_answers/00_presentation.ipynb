# %%
from IPython.display import Image

# %% [markdown]
# # geocoding
# géoréférencer un une liste de gare récupérée sur internet:
# http://www.horaires.tv/gares/liste_gare_corse.html

# %%
Image(r'../plot/gecoding.png')

# %% [markdown]
# # Open Street Map
# récupérer toutes les routes et les intersections

# %%
Image(r'../plot/edges.png')

# %% [markdown]
# # Jointure Géographique
# Associer à chaque gare et à chaque commune l'intersection viaire la plus proche

# %%
Image(r'../plot/stop_nearest_node.png')

# %%
Image(r'../plot/commune_nearest_node.png')

# %% [markdown]
# # Calcul des distances minimales en passant par le réseau routier
# - de chaque intersection vers la gare la plus proche
# - de chaque commune vers la gare la plus proche

# %%
Image(r'../plot/node_distance.png')

# %%
Image(r'../plot/commune_distance.png')

# %%
# hide code
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" 
value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit"
# value="Click here to toggle on/off the raw code."></form>
