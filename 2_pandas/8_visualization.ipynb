# %% [markdown]
# # CHAPTER 8 <font color='green'>[Essential]</font>
# ---
# Plotting and Visualization

# %%
import pandas as pd
import numpy as np
% matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
df = pd.DataFrame(list(range(20)))
df.columns = ['linear']

# %%
df.head()
# Out:
#    linear
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4

# %%
df['square'] = np.power(df['linear'], 2)
df['tenfold'] = df['linear'] * 10

# %%
import random

# %%
random.random()
# Out:
# 0.1818051463811139

# %%
help(random.random)
# Out:
# Help on built-in function random:
#
# random(...) method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
df['random'] = df['square'].apply(lambda s: (0.75 + random.random()/2) *s)
df['randint'] = df['linear'].apply(lambda s: 5* random.randint(0, int(s/2)))

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plot = df.plot()

# %%
fig = plot.get_figure()
fig.savefig(r'../plot/plot.png')

# %%
df.hist(bins=20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = [5, 5]
df.plot(kind='scatter', x='square', y='random')

# %%
values = df['randint'].value_counts()

# %%
values.plot(kind='pie')

# %%
# %matplotlib notebook
plt.rcParams['figure.figsize'] = [5, 5]
df.plot(kind='scatter', x='square', y='random')
# Out:
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="358.88889839619793">
